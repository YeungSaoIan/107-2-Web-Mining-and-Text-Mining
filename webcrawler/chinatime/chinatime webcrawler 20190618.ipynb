# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
t = requests.get("https://www.chinatimes.com/politic/total?chdtv") #將此頁面的HTML GET下來
print(t.text) #印出HTML
# Out:
# <!DOCTYPE html>
# <html lang="zh-Hant-TW">
# <head id="Head1" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta name="robots" content="index,follow,noarchive">
#     <title>總覽 -政治 - 中時電子報</title>
#     <link rel="canonical" href="https://www.chinatimes.com/politic/total">
#     <!--社群 Start-->
#     <meta property="og:url" itemprop="url" content="https://www.chinatimes.com/politic/total">
#     <meta property="og:title" itemprop="name" content="總覽-政治 - 中時電子報">
#     <meta property="og:image" itemprop="image" content="https://static.chinatimes.com/images/2019/logo-chinatimes2019-1200x635.png">
#     <meta property="og:image:width" content="1200">
#     <meta property="og:image:height" content="635">
#     <meta property="og:type" content="website">
#     <meta property="og:description" itemprop="description" content="《中時電子報》-政治總覽最新列表">
# ...

# %%
url = "https://www.chinatimes.com/politic/total?page=1&chdtv"
records = []
posts = []
for i in range(10):   
    t = requests.get(url)
    drink = BeautifulSoup(t.text,"html.parser")
    title = drink.select("h3.title a") #取<a>標籤存入giveme
    time = drink.select("div.meta-info time")#取<meta-info>標籤存入showmetime
    #print ("本頁的URL為"+url)
    url = "https://www.chinatimes.com/politic/total?page="+ str(i+2) +"&chdtv" #下一頁的網址
    for u in title:
        print(u["href"], u.text) 
        records += [u.text]
# Out:
# /realtimenews/20190619003663-260407 軍方證實：2艘加拿大籍軍艦18日航經台海
# /realtimenews/20190619003586-260407 台灣指標調查民調：韓國瑜27％勝郭台銘21％
# /realtimenews/20190619003597-260407 《中時晚間快報》排水溝塞到剩5％功能  韓嘆高雄人怎麼熬過來的？
# /realtimenews/20190619003518-260407 朱立倫林口高中玩射擊 力推青年體育部
# /realtimenews/20190619003358-260407 里長赴陸交流辭世 鄭文燦：已請海基會全力協助
# /realtimenews/20190619003305-260407 桃園市府預算減15％　鄭文燦：排除教育、人事、福利
# /realtimenews/20190619003354-260407 關懷憂鬱症患者   南市議長邀聽故鄉的歌
# /realtimenews/20190619003367-260407 挺韓大會622交通疏導 管車不管人 住戶開車出入不受影響
# /realtimenews/20190619003321-260407 桃園中正公園停車場遭反對  市府暫緩喊卡
# /realtimenews/20190619003278-260407 一句話改變韓命運？他曝絕妙關鍵
# /realtimenews/20190619003276-260407 抗議惡修公投法 藍委籲全民用選票唾棄民進黨
# /realtimenews/20190619003188-260407 國安法修正案三讀 府：進一步建構民主防護網
# /realtimenews/20190619003081-260407 行政院同意核發補助 高市府盼中央、地方攜手防疫
# /realtimenews/20190619003029-260407 不卡韓了？ 陳其邁南下視察疫情  韓國瑜陪同
# /realtimenews/20190619002954-260407 歐洲第一國！我與波蘭簽署司法合作協定
# /realtimenews/20190619002840-260407 高市沒錢防疫？ 她一查發現：花媽減列9千多萬
# ...

# %%
records[2]
# Out:
# '《中時晚間快報》排水溝塞到剩5％功能  韓嘆高雄人怎麼熬過來的？'

# %%
url = "https://www.chinatimes.com/politic/total?page=1&chdtv"
created_times = []
for i in range(10):   
    t = requests.get(url)
    drink = BeautifulSoup(t.text,"html.parser")
    time = drink.select("div.meta-info time")#取<meta-info>標籤存入showmetime
    #print ("本頁的URL為"+url)
    url = "https://www.chinatimes.com/politic/total?page="+ str(i+2) +"&chdtv" #下一頁的網址
    for v in time:
        print(v["datetime"]) 
        created_times += [v["datetime"]]
# Out:
# 2019-06-19 18:13
# 2019-06-19 17:47
# 2019-06-19 17:46
# 2019-06-19 17:42
# 2019-06-19 17:18
# 2019-06-19 17:17
# 2019-06-19 17:17
# 2019-06-19 17:09
# 2019-06-19 16:56
# 2019-06-19 16:54
# 2019-06-19 16:53
# 2019-06-19 16:27
# 2019-06-19 16:11
# 2019-06-19 16:03
# 2019-06-19 15:52
# 2019-06-19 15:41
# 2019-06-19 15:39
# 2019-06-19 15:37
# 2019-06-19 15:30
# 2019-06-19 15:26
# 2019-06-19 15:22
# 2019-06-19 15:21
# 2019-06-19 15:19
# 2019-06-19 15:18
# 2019-06-19 15:05
# 2019-06-19 15:01
# 2019-06-19 14:47
# 2019-06-19 14:47
# 2019-06-19 14:37
# 2019-06-19 14:32
# 2019-06-19 14:28
# 2019-06-19 14:24
# 2019-06-19 14:23
# 2019-06-19 14:21
# 2019-06-19 14:07
# 2019-06-19 13:57
# 2019-06-19 13:52
# 2019-06-19 13:30
# 2019-06-19 13:25
# 2019-06-19 13:03
# 2019-06-19 12:41
# 2019-06-19 12:22
# 2019-06-19 12:19
# 2019-06-19 12:16
# 2019-06-19 12:08
# 2019-06-19 12:04
# 2019-06-19 12:02
# 2019-06-19 11:59
# 2019-06-19 11:58
# 2019-06-19 11:56
# 2019-06-19 11:55
# 2019-06-19 11:34
# ...

# %%
created_times[10]
# Out:
# '2019-06-19 16:53'

# %%
#with open('chinatime.json', 'w') as f:
#    json.dump(posts, f, ensure_ascii=False, indent=2)

# %%
posts = []
for i in range(len(records)):
    title = records[i]
    created_time = created_times[i]
    post = dict(title=title, created_time=created_time)
    posts.append(post)

# %%
posts
# Out:
# [{'title': '軍方證實：2艘加拿大籍軍艦18日航經台海', 'created_time': '2019-06-19 18:13'},
#  {'title': '台灣指標調查民調：韓國瑜27％勝郭台銘21％', 'created_time': '2019-06-19 17:47'},
#  {'title': '《中時晚間快報》排水溝塞到剩5％功能  韓嘆高雄人怎麼熬過來的？',
#   'created_time': '2019-06-19 17:46'},
#  {'title': '朱立倫林口高中玩射擊 力推青年體育部', 'created_time': '2019-06-19 17:42'},
#  {'title': '里長赴陸交流辭世 鄭文燦：已請海基會全力協助', 'created_time': '2019-06-19 17:18'},
#  {'title': '桃園市府預算減15％\u3000鄭文燦：排除教育、人事、福利',
#   'created_time': '2019-06-19 17:17'},
#  {'title': '關懷憂鬱症患者   南市議長邀聽故鄉的歌', 'created_time': '2019-06-19 17:17'},
#  {'title': '挺韓大會622交通疏導 管車不管人 住戶開車出入不受影響', 'created_time': '2019-06-19 17:09'},
#  {'title': '桃園中正公園停車場遭反對  市府暫緩喊卡', 'created_time': '2019-06-19 16:56'},
#  {'title': '一句話改變韓命運？他曝絕妙關鍵', 'created_time': '2019-06-19 16:54'},
#  {'title': '抗議惡修公投法 藍委籲全民用選票唾棄民進黨', 'created_time': '2019-06-19 16:53'},
#  {'title': '國安法修正案三讀 府：進一步建構民主防護網', 'created_time': '2019-06-19 16:27'},
# ...

# %%
with open('chinatime.json', 'w') as f:
    json.dump(posts, f, ensure_ascii=False, indent=2)
