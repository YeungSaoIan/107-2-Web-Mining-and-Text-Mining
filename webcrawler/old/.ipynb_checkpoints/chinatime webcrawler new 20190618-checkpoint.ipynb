# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
t = requests.get("https://www.chinatimes.com/chinese/total?chdtv") #將此頁面的HTML GET下來
print(t.text) #印出HTML
# Out:
# <!DOCTYPE html>
# <html lang="zh-Hant-TW">
# <head id="Head1" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta name="robots" content="index,follow,noarchive">
#     <title>總覽 -兩岸 - 中時電子報</title>
#     <link rel="canonical" href="https://www.chinatimes.com/chinese/total">
#     <!--社群 Start-->
#     <meta property="og:url" itemprop="url" content="https://www.chinatimes.com/chinese/total">
#     <meta property="og:title" itemprop="name" content="總覽-兩岸 - 中時電子報">
#     <meta property="og:image" itemprop="image" content="https://static.chinatimes.com/images/2019/logo-chinatimes2019-1200x635.png">
#     <meta property="og:image:width" content="1200">
#     <meta property="og:image:height" content="635">
#     <meta property="og:type" content="website">
#     <meta property="og:description" itemprop="description" content="《中時電子報》-兩岸總覽最新列表">
# ...

# %%
url = "https://www.chinatimes.com/chinese/total?page=1&chdtv"
newsrecord = []
posts = []
for i in range(10):   
    t = requests.get(url)
    drink = BeautifulSoup(t.text,"html.parser")
    title = drink.select("h3.title a") #取<a>標籤存入giveme
    created_time = drink.select("div.meta-info time")#取<meta-info>標籤存入showmetime
    #print ("本頁的URL為"+url)
    url = "https://www.chinatimes.com/chinese/total?page="+ str(i+2) +"&chdtv" #下一頁的網址    
    post = dict(title=title, created_time=created_time)
    posts.append(post)
        
    with open('chinatime.json', 'w') as f:
        json.dump(posts, f, ensure_ascii=False, indent=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-20a52ccc33b4> in <module>()
#      13
#      14     with open('chinatime.json', 'w') as f:
# ---> 15         json.dump(posts, f, ensure_ascii=False, indent=2)
#
# ~/anaconda3/lib/python3.6/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# ~/anaconda3/lib/python3.6/json/encoder.py in _iterencode(o, _current_indent_level)
#     426             yield _floatstr(o)
#     427         elif isinstance(o, (list, tuple)):
# --> 428             yield from _iterencode_list(o, _current_indent_level)
#     429         elif isinstance(o, dict):
# ...
